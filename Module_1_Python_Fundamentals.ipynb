# %% [markdown]
# # Module 1 – Python Fundamentals
#
# This notebook covers the basic and advanced concepts of Python.
#
# ## Topics Covered
# - Basic Concepts
# - Control Flow
# - Collections
# - Functions
# - Advanced Python

# %% [markdown]
# ## Variables
#
# A variable is used to store a value.

# %%
name = "Dileep"
age = 25
score = 85.5

print(name)
print(age)
print(score)
# Out:
# Dileep
# 25
# 85.5

# %% [markdown]
# ## Data Types
#
# Python has different data types such as string, integer, float and boolean.

# %%
student_name = "Dileep"
age = 25
percentage = 82.5
is_passed = True
subjects = ["Python", "Machine Learning", "SQL"]
coordinates = (17.38, 78.48)

print("Name:", student_name, "| Type:", type(student_name))
print("Age:", age, "| Type:", type(age))
print("Percentage:", percentage, "| Type:", type(percentage))
print("Passed:", is_passed, "| Type:", type(is_passed))
print("Subjects:", subjects, "| Type:", type(subjects))
print("Coordinates:", coordinates, "| Type:", type(coordinates))
# Out:
# Name: Dileep | Type: <class 'str'>
# Age: 25 | Type: <class 'int'>
# Percentage: 82.5 | Type: <class 'float'>
# Passed: True | Type: <class 'bool'>
# Subjects: ['Python', 'Machine Learning', 'SQL'] | Type: <class 'list'>
# Coordinates: (17.38, 78.48) | Type: <class 'tuple'>

# %% [markdown]
# ## 1.3 Type Casting
#
# Type casting is the process of converting a value from one data type to another.
# Common functions include int(), float(), str() and bool().

# %%
marks = "85"
price = 499
rating = 4

marks_int = int(marks)
price_float = float(price)
rating_string = str(rating)

print("Marks:", marks_int, type(marks_int))
print("Price:", price_float, type(price_float))
print("Rating:", rating_string, type(rating_string))
# Out:
# Marks: 85 <class 'int'>
# Price: 499.0 <class 'float'>
# Rating: 4 <class 'str'>

# %% [markdown]
# ## 1.4 Operators
#
# Operators are symbols used to perform operations on variables and values.
# Python supports arithmetic, comparison, logical and assignment operators.

# %%
a = 20
b = 6

# Arithmetic operators
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)

# Comparison operators
print("a > b:", a > b)
print("a == b:", a == b)

# Logical operators
print("Both conditions:", a > 10 and b < 10)
print("Either condition:", a < 10 or b < 10)
# Out:
# Addition: 26
# Subtraction: 14
# Multiplication: 120
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 2
# a > b: True
# a == b: False
# Both conditions: True
# Either condition: True

# %% [markdown]
# ## 1.5 Input and Output
#
# The input() function is used to accept data from the user.
# The print() function is used to display the result.

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
city = input("Enter your city: ")

print("\nStudent Details")
print("----------------")
print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Enter your name:  dileep
# Enter your age:  25
# Enter your city:  Hyderabad
# Student Details
# ----------------
# Name: dileep
# Age: 25
# City: Hyderabad

# %% [markdown]
# ## 1.6 Comments
#
# Comments are used to describe the purpose of code.
# They improve code readability and are ignored during execution.

# %%
# Store employee information
employee_name = "Dileep"
employee_salary = 45000

# Calculate annual salary
annual_salary = employee_salary * 12

print("Employee:", employee_name)
print("Monthly Salary:", employee_salary)
print("Annual Salary:", annual_salary)
# Out:
# Employee: Dileep
# Monthly Salary: 45000
# Annual Salary: 540000

# %% [markdown]
# # 2. Control Flow
#
# Control flow statements are used to control the execution of a Python program
# based on conditions or repetition.
#
# Topics covered:
# - if / elif / else
# - for loop
# - while loop
# - break
# - continue
# - pass

# %% [markdown]
# ## 2.1 if / elif / else
#
# Conditional statements are used to execute different blocks of code
# depending on whether a condition is true or false.

# %%
marks = 78

if marks >= 90:
    grade = "A+"
elif marks >= 75:
    grade = "A"
elif marks >= 60:
    grade = "B"
elif marks >= 50:
    grade = "C"
else:
    grade = "Fail"

print("Marks:", marks)
print("Grade:", grade)
# Out:
# Marks: 78
# Grade: A

# %% [markdown]
# ## 2.2 for Loop
#
# A for loop is used to iterate over a sequence such as a list, tuple or string.

# %%
subjects = ["Python", "Machine Learning", "SQL", "Deep Learning"]
completed = ["Python", "SQL"]

for subject in subjects:
    if subject in completed:
        status = "Completed"
    else:
        status = "Pending"
    
    print(subject, ":", status)
# Out:
# Python : Completed
# Machine Learning : Pending
# SQL : Completed
# Deep Learning : Pending

# %% [markdown]
# ## 2.3 while Loop
#
# A while loop repeatedly executes a block of code as long as the given condition is true.

# %%
count = 1
total = 0

while count <= 5:
    total = total + count
    print("Count:", count, "Total:", total)
    count += 1

print("Final Total:", total)
# Out:
# Count: 1 Total: 1
# Count: 2 Total: 3
# Count: 3 Total: 6
# Count: 4 Total: 10
# Count: 5 Total: 15
# Final Total: 15

# %% [markdown]
# ## 2.4 break
#
# The break statement immediately terminates a loop when a specific condition is satisfied.

# %%
numbers = [10, 20, 30, 40, 50, 60]

for number in numbers:
    print("Checking:", number)
    
    if number == 40:
        print("Target number found")
        break
# Out:
# Checking: 10
# Checking: 20
# Checking: 30
# Checking: 40
# Target number found

# %% [markdown]
# ## 2.5 continue
#
# The continue statement skips the current iteration and moves to the next iteration of the loop.

# %%
numbers = range(1, 11)

for number in numbers:
    if number % 2 == 0:
        continue
    
    print("Odd number:", number)
# Out:
# Odd number: 1
# Odd number: 3
# Odd number: 5
# Odd number: 7
# Odd number: 9

# %% [markdown]
# ## 2.6 pass
#
# The pass statement is a placeholder used when a statement is syntactically required
# but no action needs to be performed yet.

# %%
numbers = [10, 20, 30, 40]

for number in numbers:
    if number == 30:
        pass
    else:
        print("Processing:", number)

print("Loop completed")
# Out:
# Processing: 10
# Processing: 20
# Processing: 40
# Loop completed

# %% [markdown]
# # 3. Collections
#
# Python collections are used to store and organize multiple values.
#
# Topics covered:
# - List
# - Tuple
# - Set
# - Dictionary
# - List Comprehension
# - Dictionary Comprehension

# %% [markdown]
# ## 3.1 List
#
# A list is an ordered and mutable collection.
# It allows duplicate values and can store different data types.

# %%
skills = ["Python", "SQL", "Machine Learning", "Python"]

print("Original list:", skills)

# Add a new skill
skills.append("Deep Learning")

# Update an existing value
skills[1] = "Advanced SQL"

# Remove a value
skills.remove("Python")

print("Updated list:", skills)
print("Number of skills:", len(skills))
print("First skill:", skills[0])
# Out:
# Original list: ['Python', 'SQL', 'Machine Learning', 'Python']
# Updated list: ['Advanced SQL', 'Machine Learning', 'Python', 'Deep Learning']
# Number of skills: 4
# First skill: Advanced SQL

# %% [markdown]
# ## 3.2 Tuple
#
# A tuple is an ordered and immutable collection.
# Once created, its elements cannot be changed.

# %%
employee = ("Dileep", "AI/ML Engineer", 25, "Hyderabad")

print("Employee details:", employee)
print("Name:", employee[0])
print("Role:", employee[1])
print("Number of details:", len(employee))

# Tuple unpacking
name, role, age, city = employee

print("\nUnpacked values:")
print("Name:", name)
print("Role:", role)
print("Age:", age)
print("City:", city)
# Out:
# Employee details: ('Dileep', 'AI/ML Engineer', 25, 'Hyderabad')
# Name: Dileep
# Role: AI/ML Engineer
# Number of details: 4
#
# Unpacked values:
# Name: Dileep
# Role: AI/ML Engineer
# Age: 25
# City: Hyderabad

# %% [markdown]
# ## 3.3 Set
#
# A set is an unordered collection of unique elements.
# It automatically removes duplicate values.

# %%
skills = {"Python", "SQL", "Machine Learning", "Python", "SQL"}

print("Original set:", skills)

skills.add("Deep Learning")
skills.remove("SQL")

print("Updated set:", skills)
print("Number of unique skills:", len(skills))
# Out:
# Original set: {'Python', 'Machine Learning', 'SQL'}
# Updated set: {'Python', 'Machine Learning', 'Deep Learning'}
# Number of unique skills: 3

# %% [markdown]
# ## 3.4 Dictionary
#
# A dictionary stores data in key-value pairs.
# It is useful when each value needs a meaningful key.

# %%
student = {
    "name": "Dileep",
    "age": 25,
    "course": "AI/ML",
    "marks": 85
}

print("Student details:")
print("Name:", student["name"])
print("Course:", student["course"])
print("Marks:", student["marks"])

# Update marks
student["marks"] = 90

# Add a new key-value pair
student["grade"] = "A"

print("\nUpdated student details:")
for key, value in student.items():
    print(key, ":", value)
# Out:
# Student details:
# Name: Dileep
# Course: AI/ML
# Marks: 85
#
# Updated student details:
# name : Dileep
# age : 25
# course : AI/ML
# marks : 90
# grade : A

# %% [markdown]
# ## 3.5 List Comprehension
#
# List comprehension provides a short and readable way to create a new list
# from an existing iterable.

# %%
numbers = range(1, 11)

# Create squares of even numbers
even_squares = [number ** 2 for number in numbers if number % 2 == 0]

print("Even numbers:", [number for number in numbers if number % 2 == 0])
print("Squares of even numbers:", even_squares)
# Out:
# Even numbers: [2, 4, 6, 8, 10]
# Squares of even numbers: [4, 16, 36, 64, 100]

# %% [markdown]
# ## 3.6 Dictionary Comprehension
#
# Dictionary comprehension provides a concise way to create dictionaries
# using an iterable and an expression.

# %%
numbers = range(1, 6)

squares = {number: number ** 2 for number in numbers}

print("Square dictionary:", squares)

# Create a dictionary only for even numbers
even_squares = {
    number: number ** 2
    for number in numbers
    if number % 2 == 0
}

print("Even square dictionary:", even_squares)
# Out:
# Square dictionary: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# Even square dictionary: {2: 4, 4: 16}

# %% [markdown]
# # 4. Functions
#
# A function is a reusable block of code designed to perform a specific task.
#
# Topics covered:
# - Function Definition
# - Arguments
# - Default Arguments
# - Keyword Arguments
# - Variable-Length Arguments (*args, **kwargs)
# - Lambda Functions
# - Recursive Functions

# %% [markdown]
# ## 4.1 Function Definition
#
# A function is defined using the `def` keyword.
# Functions help us avoid repeating the same code multiple times.

# %%
def calculate_average(marks):
    total = sum(marks)
    average = total / len(marks)
    return average


student_marks = [78, 85, 92, 88, 76]

average_marks = calculate_average(student_marks)

print("Marks:", student_marks)
print("Average Marks:", round(average_marks, 2))
# Out:
# Marks: [78, 85, 92, 88, 76]
# Average Marks: 83.8

# %% [markdown]
# ## 4.2 Arguments
#
# Arguments are values passed to a function when the function is called.

# %%
def calculate_salary(basic_salary, bonus):
    total_salary = basic_salary + bonus
    return total_salary


basic = 40000
bonus = 5000

salary = calculate_salary(basic, bonus)

print("Basic Salary:", basic)
print("Bonus:", bonus)
print("Total Salary:", salary)
# Out:
# Basic Salary: 40000
# Bonus: 5000
# Total Salary: 45000

# %% [markdown]
# ## 4.3 Default Arguments
#
# A default argument has a predefined value.
# If the caller does not provide that argument, the default value is used.

# %%
def greet_user(name, role="Python Developer"):
    print("Name:", name)
    print("Role:", role)


greet_user("Dileep")

print()

greet_user("Rahul", "Data Scientist")
# Out:
# Name: Dileep
# Role: Python Developer
#
# Name: Rahul
# Role: Data Scientist

# %% [markdown]
# ## 4.4 Keyword Arguments
#
# Keyword arguments allow us to pass values using the parameter names.
# The order of arguments does not matter when using parameter names.

# %%
def employee_details(name, age, department, experience):
    print("Name:", name)
    print("Age:", age)
    print("Department:", department)
    print("Experience:", experience, "years")


employee_details(
    experience=2,
    department="AI/ML",
    name="Dileep",
    age=25
)
# Out:
# Name: Dileep
# Age: 25
# Department: AI/ML
# Experience: 2 years

# %% [markdown]
# ## 4.5 Variable-Length Arguments - *args
#
# `*args` allows a function to accept any number of positional arguments.
# The arguments are received as a tuple.

# %%
def calculate_total(*numbers):
    total = 0
    
    for number in numbers:
        total += number
    
    return total


print("Total 1:", calculate_total(10, 20, 30))
print("Total 2:", calculate_total(5, 15, 25, 35, 45))
# Out:
# Total 1: 60
# Total 2: 125

# %% [markdown]
# ## 4.6 Variable-Length Arguments - **kwargs
#
# `**kwargs` allows a function to accept any number of keyword arguments.
# The arguments are received as a dictionary.

# %%
def display_profile(**details):
    print("Employee Profile")
    
    for key, value in details.items():
        print(key, ":", value)


display_profile(
    name="Dileep",
    role="AI/ML Engineer",
    location="Hyderabad",
    experience=2
)
# Out:
# Employee Profile
# name : Dileep
# role : AI/ML Engineer
# location : Hyderabad
# experience : 2

# %% [markdown]
# ## 4.7 Lambda Functions
#
# A lambda function is a small anonymous function.
# It can take multiple arguments but contains a single expression.

# %%
numbers = [2, 4, 6, 8, 10]

square = lambda x: x ** 2

squared_numbers = [square(number) for number in numbers]

print("Original numbers:", numbers)
print("Squared numbers:", squared_numbers)
# Out:
# Original numbers: [2, 4, 6, 8, 10]
# Squared numbers: [4, 16, 36, 64, 100]

# %% [markdown]
# ## 4.8 Recursive Functions
#
# A recursive function is a function that calls itself.
# It must have a base condition to stop the recursion.

# %%
def factorial(number):
    if number == 0 or number == 1:
        return 1
    
    return number * factorial(number - 1)


number = 5
result = factorial(number)

print("Number:", number)
print("Factorial:", result)
# Out:
# Number: 5
# Factorial: 120

# %% [markdown]
# # 5. Advanced Python
#
# This section covers advanced Python concepts that help in writing
# efficient, reusable and flexible programs.
#
# Topics covered:
# - Iterators
# - Generators
# - yield
# - Decorators
# - Closures

# %% [markdown]
# ## 5.1 Iterators
#
# An iterator is an object that allows us to access elements one at a time.
#
# The `iter()` function creates an iterator, and `next()` retrieves
# the next available element.

# %%
numbers = [10, 20, 30, 40, 50]

number_iterator = iter(numbers)

print("First value:", next(number_iterator))
print("Second value:", next(number_iterator))
print("Third value:", next(number_iterator))

print("\nRemaining values:")
for number in number_iterator:
    print(number)
# Out:
# First value: 10
# Second value: 20
# Third value: 30
#
# Remaining values:
# 40
# 50

# %% [markdown]
# ## 5.2 Generators
#
# A generator is a special type of iterator that produces values one at a time.
# Generators are memory efficient because they do not store all values at once.

# %%
def square_generator(numbers):
    for number in numbers:
        yield number ** 2


numbers = [1, 2, 3, 4, 5]

squares = square_generator(numbers)

for square in squares:
    print("Square:", square)
# Out:
# Square: 1
# Square: 4
# Square: 9
# Square: 16
# Square: 25

# %% [markdown]
# ## 5.3 yield
#
# The `yield` keyword is used inside a generator function.
# Unlike `return`, `yield` pauses the function and remembers its state,
# allowing it to continue from where it stopped.

# %%
def even_numbers(limit):
    for number in range(1, limit + 1):
        if number % 2 == 0:
            yield number


numbers = even_numbers(10)

print("Even numbers:")

for number in numbers:
    print(number)
# Out:
# Even numbers:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## 5.4 Decorators
#
# A decorator is a function that modifies or extends the behavior
# of another function without changing its original code.

# %%
def log_function(func):
    def wrapper():
        print("Function execution started")
        func()
        print("Function execution completed")
    
    return wrapper


@log_function
def show_message():
    print("Welcome to Python programming")


show_message()
# Out:
# Function execution started
# Welcome to Python programming
# Function execution completed

# %%
def check_access(func):
    def wrapper(role):
        if role == "admin":
            return func(role)
        else:
            print("Access denied")
    
    return wrapper


@check_access
def admin_dashboard(role):
    print("Welcome to the admin dashboard")


admin_dashboard("admin")
admin_dashboard("user")
# Out:
# Welcome to the admin dashboard
# Access denied

# %% [markdown]
# ## 5.6 Closures
#
# A closure occurs when an inner function remembers and uses variables
# from its outer function even after the outer function has finished execution.

# %%
def create_multiplier(multiplier):
    
    def multiply(number):
        return number * multiplier
    
    return multiply


double = create_multiplier(2)
triple = create_multiplier(3)

print("Double of 10:", double(10))
print("Triple of 10:", triple(10))
# Out:
# Double of 10: 20
# Triple of 10: 30

# %% [markdown]
# ## 5.6 global and nonlocal
#
# The `global` keyword is used to modify a variable defined outside a function
# at the global scope.
#
# The `nonlocal` keyword is used inside a nested function to modify a variable
# defined in its enclosing function.

# %%
# Example of global

counter = 0

def increase_counter():
    global counter
    counter += 1
    return counter


print("Counter:", increase_counter())
print("Counter:", increase_counter())
print("Counter:", increase_counter())
# Out:
# Counter: 1
# Counter: 2
# Counter: 3

# %% [markdown]
# ## 5.7 Modules
#
# A module is a Python file containing functions, variables or classes
# that can be reused in another Python program.
#
# Python also provides many built-in modules such as math, random and datetime.

# %%
import math
import random

number = 25

print("Square root:", math.sqrt(number))
print("Power:", math.pow(2, 3))
print("Random number:", random.randint(1, 10))
# Out:
# Square root: 5.0
# Power: 8.0
# Random number: 3

# %% [markdown]
# ## 5.8 Packages
#
# A package is a collection of related Python modules organized in a directory.
# Packages help organize large Python projects into smaller and manageable components.

# %%
# Example package structure

# mypackage/
#     __init__.py
#     calculator.py
#     message.py

# calculator.py
def add(a, b):
    return a + b

# In another Python file we can use:
# from mypackage.calculator import add

# result = add(10, 20)
# print("Result:", result)

# %% [markdown]
# ## 5.9 Type Hinting
#
# Type hints are used to indicate the expected data types of variables,
# function parameters and return values.
#
# They improve code readability and help tools detect potential type-related issues.

# %%
def calculate_total(price: float, quantity: int) -> float:
    total: float = price * quantity
    return total


price: float = 499.50
quantity: int = 3

total: float = calculate_total(price, quantity)

print("Price:", price)
print("Quantity:", quantity)
print("Total:", total)
# Out:
# Price: 499.5
# Quantity: 3
# Total: 1498.5

# %% [markdown]
# # 6. Built-in Functions
#
# Python provides several built-in functions that make common programming
# tasks easier and reduce the need to write repetitive code.
#
# Topics covered:
# - map()
# - filter()
# - zip()
# - enumerate()
# - sorted()
# - any()
# - all()
# - isinstance()
# - id()

# %% [markdown]
# ## 6.1 map()
#
# The map() function applies a function to every element of an iterable
# and returns an iterator containing the results.

# %%
numbers = [1, 2, 3, 4, 5]

squared_numbers = list(map(lambda x: x ** 2, numbers))

print("Original numbers:", numbers)
print("Squared numbers:", squared_numbers)
# Out:
# Original numbers: [1, 2, 3, 4, 5]
# Squared numbers: [1, 4, 9, 16, 25]

# %% [markdown]
# ## 6.2 filter()
#
# The filter() function selects elements from an iterable based on a condition.

# %%
numbers = [10, 15, 20, 25, 30, 35]

even_numbers = list(filter(lambda x: x % 2 == 0, numbers))

print("Original numbers:", numbers)
print("Even numbers:", even_numbers)
# Out:
# Original numbers: [10, 15, 20, 25, 30, 35]
# Even numbers: [10, 20, 30]

# %% [markdown]
# ## 6.3 zip()
#
# The zip() function combines two or more iterables element by element.
# It pairs the values based on their position.

# %%
names = ["Dileep", "Rahul", "Anil", "Kiran"]
marks = [85, 92, 78, 88]

student_details = list(zip(names, marks))

print("Student Details:")

for name, mark in student_details:
    print(name, ":", mark)
# Out:
# Student Details:
# Dileep : 85
# Rahul : 92
# Anil : 78
# Kiran : 88

# %% [markdown]
# ## 6.4 enumerate()
#
# The enumerate() function is used to iterate through a sequence while
# keeping track of the index and the value at the same time.

# %%
skills = ["Python", "SQL", "Machine Learning", "Deep Learning"]

print("Skills List:")

for index, skill in enumerate(skills, start=1):
    print(index, "-", skill)
# Out:
# Skills List:
# 1 - Python
# 2 - SQL
# 3 - Machine Learning
# 4 - Deep Learning

# %% [markdown]
# ## 6.5 sorted()
#
# The sorted() function returns a new list containing the elements of an
# iterable in sorted order. It can sort values in ascending or descending order.

# %%
numbers = [45, 12, 78, 23, 56, 9]

ascending = sorted(numbers)
descending = sorted(numbers, reverse=True)

print("Original list:", numbers)
print("Ascending order:", ascending)
print("Descending order:", descending)
# Out:
# Original list: [45, 12, 78, 23, 56, 9]
# Ascending order: [9, 12, 23, 45, 56, 78]
# Descending order: [78, 56, 45, 23, 12, 9]

# %% [markdown]
# ## 6.6 any()
#
# The any() function checks whether at least one element in an iterable
# is True. It returns True if any condition is satisfied; otherwise,
# it returns False.

# %%
marks = [45, 38, 72, 41, 35]

passed_students = [mark >= 50 for mark in marks]

print("Marks:", marks)
print("Pass conditions:", passed_students)
print("At least one student passed:", any(passed_students))
# Out:
# Marks: [45, 38, 72, 41, 35]
# Pass conditions: [False, False, True, False, False]
# At least one student passed: True

# %% [markdown]
# ## 6.7 all()
#
# The all() function checks whether every element in an iterable is True.
# It returns True only when all conditions are satisfied.

# %%
marks = [65, 72, 81, 90, 76]

passed_students = [mark >= 50 for mark in marks]

print("Marks:", marks)
print("Pass conditions:", passed_students)
print("All students passed:", all(passed_students))
# Out:
# Marks: [65, 72, 81, 90, 76]
# Pass conditions: [True, True, True, True, True]
# All students passed: True

# %% [markdown]
# ## 6.8 isinstance()
#
# The isinstance() function is used to check whether an object belongs
# to a particular data type or class.
#
# It returns True if the object matches the specified type; otherwise,
# it returns False.

# %%
name = "Dileep"
age = 25
marks = [85, 90, 78]
percentage = 82.5

print("Is name a string?", isinstance(name, str))
print("Is age an integer?", isinstance(age, int))
print("Are marks a list?", isinstance(marks, list))
print("Is percentage a float?", isinstance(percentage, float))
print("Is age a string?", isinstance(age, str))
# Out:
# Is name a string? True
# Is age an integer? True
# Are marks a list? True
# Is percentage a float? True
# Is age a string? False

# %% [markdown]
# ## 6.9 id()
#
# The id() function returns the unique identity of an object during
# its lifetime.
#
# It can be used to check whether two variables refer to the same object.

# %%
numbers = [10, 20, 30]

same_numbers = numbers
different_numbers = [10, 20, 30]

print("ID of numbers:", id(numbers))
print("ID of same_numbers:", id(same_numbers))
print("ID of different_numbers:", id(different_numbers))

print("\nDo numbers and same_numbers have the same ID?",
      id(numbers) == id(same_numbers))

print("Do numbers and different_numbers have the same ID?",
      id(numbers) == id(different_numbers))
# Out:
# ID of numbers: 2612534846784
# ID of same_numbers: 2612534846784
# ID of different_numbers: 2612534847104
#
# Do numbers and same_numbers have the same ID? True
# Do numbers and different_numbers have the same ID? False

# %% [markdown]
# ## module2. Class
#
# A class is a blueprint for creating objects in Python.
#
# It defines the attributes (data) and methods (behavior) that objects created from the class can have.

# %%
class Student:
    name = "Dileep"
    course = "AI/ML"

    def display_details(self):
        print("Student Name:", self.name)
        print("Course:", self.course)


student = Student()
student.display_details()
# Out:
# Student Name: Dileep
# Course: AI/ML

# %% [markdown]
# ## 2.2. Object
#
# An object is an instance of a class.
#
# Objects are created using the class and can access the attributes and methods defined in that class.

# %%
class Student:
    def __init__(self, name, course):
        self.name = name
        self.course = course

    def display_details(self):
        print("Name:", self.name)
        print("Course:", self.course)


student1 = Student("Dileep", "AI/ML")
student2 = Student("Rahul", "Data Science")

student1.display_details()
student2.display_details()
# Out:
# Name: Dileep
# Course: AI/ML
# Name: Rahul
# Course: Data Science

# %% [markdown]
# ## 2.3. Constructor (__init__)
#
# The __init__() method is a special method in Python that is automatically
# called when an object is created.
#
# It is used to initialize the instance variables of an object.

# %%
class Employee:
    def __init__(self, name, role, salary):
        self.name = name
        self.role = role
        self.salary = salary

    def display_details(self):
        print("Employee Name:", self.name)
        print("Role:", self.role)
        print("Salary:", self.salary)


employee1 = Employee("Dileep", "AI/ML Engineer", 50000)
employee2 = Employee("Rahul", "Data Analyst", 45000)

employee1.display_details()
print()
employee2.display_details()
# Out:
# Employee Name: Dileep
# Role: AI/ML Engineer
# Salary: 50000
#
# Employee Name: Rahul
# Role: Data Analyst
# Salary: 45000

# %% [markdown]
# ## 2.4. Instance Variables
#
# Instance variables are variables that belong to an individual object.
# They are usually defined inside the __init__() method using self.

# %%
class Employee:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def display(self):
        print("Name:", self.name)
        print("Role:", self.role)


employee1 = Employee("Dileep", "AI/ML Engineer")
employee2 = Employee("Rahul", "Data Analyst")

employee1.display()
employee2.display()
# Out:
# Name: Dileep
# Role: AI/ML Engineer
# Name: Rahul
# Role: Data Analyst

# %% [markdown]
# ## 2.5. Class Variables
#
# A class variable is a variable that is shared by all objects of a class.
# It is defined inside the class but outside the instance methods.

# %%
class Employee:
    company = "Tech Solutions"

    def __init__(self, name, role):
        self.name = name
        self.role = role

    def display(self):
        print("Name:", self.name)
        print("Role:", self.role)
        print("Company:", Employee.company)


employee1 = Employee("Dileep", "AI/ML Engineer")
employee2 = Employee("Rahul", "Data Analyst")

employee1.display()
print()
employee2.display()
# Out:
# Name: Dileep
# Role: AI/ML Engineer
# Company: Tech Solutions
#
# Name: Rahul
# Role: Data Analyst
# Company: Tech Solutions

# %% [markdown]
# ## 2.6. Instance Methods
#
# Instance methods are methods that operate on the data of a specific object.
# They use self as the first parameter.

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display_details(self):
        print("Name:", self.name)
        print("Salary:", self.salary)

    def increase_salary(self, amount):
        self.salary += amount


employee = Employee("Dileep", 50000)

employee.display_details()

employee.increase_salary(5000)

print("After Salary Increase:")
employee.display_details()
# Out:
# Name: Dileep
# Salary: 50000
# After Salary Increase:
# Name: Dileep
# Salary: 55000

# %% [markdown]
# ## 2.7. Static Methods
#
# A static method is a method that does not depend on instance or class variables.
# It is defined using the @staticmethod decorator.

# %%
class Calculator:
    
    @staticmethod
    def add_numbers(a, b):
        return a + b

    @staticmethod
    def multiply_numbers(a, b):
        return a * b


result1 = Calculator.add_numbers(20, 10)
result2 = Calculator.multiply_numbers(20, 10)

print("Addition:", result1)
print("Multiplication:", result2)
# Out:
# Addition: 30
# Multiplication: 200

# %% [markdown]
# ## 2.8. Class Methods
#
# A class method is a method that works with class-level data.
# It uses cls as the first parameter and is defined using @classmethod.

# %%
class Employee:
    company = "Tech Solutions"

    def __init__(self, name, role):
        self.name = name
        self.role = role

    @classmethod
    def change_company(cls, new_company):
        cls.company = new_company

    def display(self):
        print("Name:", self.name)
        print("Role:", self.role)
        print("Company:", self.company)


employee1 = Employee("Dileep", "AI/ML Engineer")
employee2 = Employee("Rahul", "Data Analyst")

Employee.change_company("AI Technologies")

employee1.display()
print()
employee2.display()
# Out:
# Name: Dileep
# Role: AI/ML Engineer
# Company: AI Technologies
#
# Name: Rahul
# Role: Data Analyst
# Company: AI Technologies

# %% [markdown]
# ## 2.9. Properties (@property)
#
# The @property decorator allows a method to be accessed like an attribute.
# It is commonly used to control access to object data.

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self._salary = salary

    @property
    def salary(self):
        return self._salary

    @salary.setter
    def salary(self, value):
        if value > 0:
            self._salary = value
        else:
            print("Salary must be greater than zero")


employee = Employee("Dileep", 50000)

print("Current Salary:", employee.salary)

employee.salary = 60000

print("Updated Salary:", employee.salary)
# Out:
# Current Salary: 50000
# Updated Salary: 60000

# %% [markdown]
# ## 2.10. Encapsulation
#
# Encapsulation is the concept of bundling data and methods together inside a class
# and controlling access to the internal data.

# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def get_balance(self):
        return self.__balance


account = BankAccount("Dileep", 10000)

account.deposit(5000)

print("Account Holder:", account.account_holder)
print("Balance:", account.get_balance())
# Out:
# Account Holder: Dileep
# Balance: 15000

# %% [markdown]
# ## 2.11. Abstraction
#
# Abstraction hides the internal implementation details and exposes only
# the necessary functionality to the user.

# %%
from abc import ABC, abstractmethod


class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass


class Car(Vehicle):

    def start(self):
        print("Car starts using an engine")


class ElectricCar(Vehicle):

    def start(self):
        print("Electric car starts using a battery")


car = Car()
electric_car = ElectricCar()

car.start()
electric_car.start()
# Out:
# Car starts using an engine
# Electric car starts using a battery

# %% [markdown]
# ## 2.12. Inheritance
#
# Inheritance allows a child class to inherit attributes and methods
# from a parent class.
#
# It promotes code reusability.

# %%
class Employee:
    def __init__(self, name):
        self.name = name

    def display_name(self):
        print("Employee Name:", self.name)


class Developer(Employee):
    def write_code(self):
        print(self.name, "is writing Python code")


developer = Developer("Dileep")

developer.display_name()
developer.write_code()
# Out:
# Employee Name: Dileep
# Dileep is writing Python code

# %% [markdown]
# ## 2.13. Multiple Inheritance
#
# Multiple inheritance allows a child class to inherit
# features from two or more parent classes.

# %%
class Programmer:
    def write_code(self):
        print("Writing Python code")


class DataScientist:
    def analyze_data(self):
        print("Analyzing data")


class AIEngineer(Programmer, DataScientist):
    def build_model(self):
        print("Building a machine learning model")


engineer = AIEngineer()

engineer.write_code()
engineer.analyze_data()
engineer.build_model()
# Out:
# Writing Python code
# Analyzing data
# Building a machine learning model

# %% [markdown]
# ## 2.14. Multilevel Inheritance
#
# Multilevel inheritance occurs when a class inherits from another derived class,
# forming a chain of inheritance.

# %%
class Person:
    def show_person(self):
        print("This is a person")


class Employee(Person):
    def show_employee(self):
        print("This is an employee")


class Developer(Employee):
    def show_developer(self):
        print("This is a developer")


developer = Developer()

developer.show_person()
developer.show_employee()
developer.show_developer()
# Out:
# This is a person
# This is an employee
# This is a developer

# %% [markdown]
# ## 2.15. Hierarchical Inheritance
#
# Hierarchical inheritance occurs when multiple child classes
# inherit from the same parent class.

# %%
class Employee:
    def show_company(self):
        print("Company: Tech Solutions")


class Developer(Employee):
    def write_code(self):
        print("Developer writes Python code")


class Tester(Employee):
    def test_application(self):
        print("Tester tests the application")


developer = Developer()
tester = Tester()

developer.show_company()
developer.write_code()

print()

tester.show_company()
tester.test_application()
# Out:
# Company: Tech Solutions
# Developer writes Python code
#
# Company: Tech Solutions
# Tester tests the application

# %% [markdown]
# ## 2.16. Polymorphism
#
# Polymorphism means "many forms".
#
# It allows the same method or interface to perform different
# actions depending on the object using it.

# %%
class Developer:
    def work(self):
        print("Developer writes and maintains code")


class DataScientist:
    def work(self):
        print("Data Scientist analyzes data and builds models")


class Tester:
    def work(self):
        print("Tester tests the application")


employees = [Developer(), DataScientist(), Tester()]

for employee in employees:
    employee.work()
# Out:
# Developer writes and maintains code
# Data Scientist analyzes data and builds models
# Tester tests the application

# %% [markdown]
# ## 2.17. Method Overriding
#
# Method overriding occurs when a child class provides its own
# implementation of a method that is already defined in the parent class.

# %%
class Employee:
    def work(self):
        print("Employee performs general work")


class Developer(Employee):
    def work(self):
        print("Developer writes Python code")


class Manager(Employee):
    def work(self):
        print("Manager manages the development team")


employee = Employee()
developer = Developer()
manager = Manager()

employee.work()
developer.work()
manager.work()
# Out:
# Employee performs general work
# Developer writes Python code
# Manager manages the development team

# %% [markdown]
# ## 2.18. Method Overloading (Python Approach)
#
# Python does not support traditional method overloading.
# We can achieve similar behavior using default arguments or *args.

# %%
class Calculator:

    def add(self, a, b=0, c=0):
        return a + b + c


calculator = Calculator()

print("Two numbers:", calculator.add(10, 20))
print("Three numbers:", calculator.add(10, 20, 30))
# Out:
# Two numbers: 30
# Three numbers: 60

# %% [markdown]
# ## 2.19. Composition
#
# Composition is a "has-a" relationship where one class contains
# an object of another class.
#
# The contained object is strongly associated with the main object.

# %%
class Engine:
    def start(self):
        print("Engine started")


class Car:
    def __init__(self):
        self.engine = Engine()

    def start_car(self):
        self.engine.start()
        print("Car started")


car = Car()
car.start_car()
# Out:
# Engine started
# Car started

# %% [markdown]
# ## 2.20. Aggregation
#
# Aggregation is a weak "has-a" relationship between classes.
#
# The contained objects can exist independently of the object that uses them.

# %%
class Employee:
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Employee:", self.name)


class Department:
    def __init__(self, name, employees):
        self.name = name
        self.employees = employees

    def display_employees(self):
        print("Department:", self.name)
        for employee in self.employees:
            employee.display()


employee1 = Employee("Dileep")
employee2 = Employee("Rahul")

employees = [employee1, employee2]

department = Department("AI/ML", employees)
department.display_employees()
# Out:
# Department: AI/ML
# Employee: Dileep
# Employee: Rahul

# %% [markdown]
# ## 2.21. Association
#
# Association represents a relationship between two independent classes.
#
# The objects can exist independently but interact with each other.

# %%
class Student:
    def __init__(self, name):
        self.name = name


class Teacher:
    def __init__(self, name):
        self.name = name

    def teach(self, student):
        print(self.name, "is teaching", student.name)


student = Student("Dileep")
teacher = Teacher("Anil")

teacher.teach(student)
# Out:
# Anil is teaching Dileep

# %% [markdown]
# ## 2.22. Magic / Dunder Methods
#
# Magic methods, also called dunder methods, are special methods
# with double underscores before and after their names.
#
# They allow objects to work with Python's built-in operations.

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def __str__(self):
        return f"Student: {self.name}, Marks: {self.marks}"

    def __len__(self):
        return len(self.marks)


student = Student("Dileep", [85, 90, 88])

print(student)
print("Number of subjects:", len(student))
# Out:
# Student: Dileep, Marks: [85, 90, 88]
# Number of subjects: 3

# %% [markdown]
# ## 2.23. super()
#
# The super() function is used to access methods and attributes
# of the parent class from a child class.

# %%
class Employee:
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Employee Name:", self.name)


class Developer(Employee):
    def __init__(self, name, language):
        super().__init__(name)
        self.language = language

    def display(self):
        super().display()
        print("Programming Language:", self.language)


developer = Developer("Dileep", "Python")
developer.display()
# Out:
# Employee Name: Dileep
# Programming Language: Python

# %% [markdown]
# ## 2.24. __str__()
#
# The __str__() method defines a user-friendly string representation
# of an object.
#
# It is automatically called when the object is passed to print().

# %%
class Employee:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def __str__(self):
        return f"{self.name} - {self.role}"


employee = Employee("Dileep", "AI/ML Engineer")

print(employee)
# Out:
# Dileep - AI/ML Engineer

# %% [markdown]
# ## 2.25. __repr__()
#
# The __repr__() method provides a detailed representation of an object,
# mainly intended for developers and debugging.

# %%
class Employee:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def __repr__(self):
        return f"Employee(name='{self.name}', role='{self.role}')"


employee = Employee("Dileep", "AI/ML Engineer")

print(repr(employee))
# Out:
# Employee(name='Dileep', role='AI/ML Engineer')

# %% [markdown]
# ## 2.26. __len__()
#
# The __len__() method allows an object to define its own length.
#
# It is automatically called when the len() function is used.

# %%
class Student:
    def __init__(self, subjects):
        self.subjects = subjects

    def __len__(self):
        return len(self.subjects)


student = Student(["Python", "SQL", "Machine Learning", "Deep Learning"])

print("Number of Subjects:", len(student))
# Out:
# Number of Subjects: 4

# %% [markdown]
# ## 2.27. Dataclasses
#
# Dataclasses help reduce boilerplate code by automatically generating
# methods such as __init__(), __repr__() and __eq__().

# %%
from dataclasses import dataclass

@dataclass
class Employee:
    name: str
    role: str
    salary: int


employee = Employee(
    name="Dileep",
    role="AI/ML Engineer",
    salary=50000
)

print(employee)
# Out:
# Employee(name='Dileep', role='AI/ML Engineer', salary=50000)

# %% [markdown]
# ## 2.28. Singleton Pattern
#
# The Singleton Pattern ensures that only one instance of a class
# is created throughout the program.
#
# It is useful when we need a single shared object, such as a
# configuration manager or application settings.

# %%
class Singleton:
    _instance = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
        return cls._instance


object1 = Singleton()
object2 = Singleton()

print("Object 1:", object1)
print("Object 2:", object2)
print("Same Object:", object1 is object2)
# Out:
# Object 1: <__main__.Singleton object at 0x000002604736B950>
# Object 2: <__main__.Singleton object at 0x000002604736B950>
# Same Object: True

# %% [markdown]
# # Module 3 – Exception Handling
#
# This module explains how to handle errors and exceptions in Python.
#
# ### Topics Covered
#
# - 3.1 try
# - 3.2 except
# - 3.3 else
# - 3.4 finally
# - 3.5 raise
# - 3.6 assert
# - 3.7 Custom Exceptions

# %% [markdown]
# ## 3.1 try
#
# The try block contains code that may raise an exception.
# Python attempts to execute the statements inside the try block.

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print("Result:", result)
except ValueError:
    print("Please enter a valid number.")
except ZeroDivisionError:
    print("Number cannot be zero.")
# Out:
# Enter a number:  20
# Result: 5.0

# %% [markdown]
# ## 3.2 except
#
# The except block is used to catch and handle exceptions
# that occur inside the try block.

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print("Result:", result)

except ValueError:
    print("Invalid input. Please enter a number.")

except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Enter a number:  0
# Cannot divide by zero.

# %% [markdown]
# ## 3.3 else
#
# The else block executes when the try block completes successfully
# without raising an exception.

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number

except ValueError:
    print("Invalid input.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

else:
    print("Calculation successful.")
    print("Result:", result)
# Out:
# Enter a number:  20
# Calculation successful.
# Result: 5.0

# %% [markdown]
# ## 3.4 finally
#
# The finally block always executes whether an exception occurs or not.
# It is commonly used for cleanup operations.

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print("Result:", result)

except ValueError:
    print("Invalid input.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

finally:
    print("Execution completed.")
# Out:
# Enter a number:  10
# Result: 10.0
# Execution completed.

# %% [markdown]
# ## 3.5 raise
#
# The raise statement is used to manually raise an exception
# when a specific condition is not satisfied.

# %%
def check_age(age):
    if age < 18:
        raise ValueError("Age must be 18 or above.")

    print("Eligible for registration.")


try:
    check_age(20)
except ValueError as error:
    print("Error:", error)
# Out:
# Eligible for registration.

# %% [markdown]
# ## 3.6 assert
#
# The assert statement checks whether a condition is true.
# If the condition is false, Python raises an AssertionError.

# %%
def calculate_discount(price):
    assert price > 0, "Price must be greater than zero."

    discount = price * 0.10
    return price - discount


final_price = calculate_discount(1000)

print("Final Price:", final_price)
# Out:
# Final Price: 900.0

# %% [markdown]
# ## 3.7 Custom Exceptions
#
# Custom exceptions are user-defined exceptions created for
# specific application requirements.
#
# They are created by inheriting from the built-in Exception class.

# %%
class InsufficientBalanceError(Exception):
    pass


class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount > self.balance:
            raise InsufficientBalanceError("Insufficient account balance.")

        self.balance -= amount
        print("Withdrawal successful.")
        print("Remaining Balance:", self.balance)


account = BankAccount(10000)

try:
    account.withdraw(12000)
except InsufficientBalanceError as error:
    print("Error:", error)
# Out:
# Error: Insufficient account balance.

# %% [markdown]
# ## 3.8 ValueError
#
# ValueError occurs when a function receives a value with the correct
# data type but an inappropriate value.
#
# Example: converting a non-numeric string into an integer.

# %%
try:
    age = int("twenty")
    print("Age:", age)

except ValueError as error:
    print("ValueError handled:", error)
# Out:
# ValueError handled: invalid literal for int() with base 10: 'twenty'

# %% [markdown]
# ## 3.9 TypeError
#
# TypeError occurs when an operation is performed on incompatible
# data types.

# %%
try:
    number = 10
    text = "20"

    result = number + text
    print("Result:", result)

except TypeError as error:
    print("TypeError handled:", error)
# Out:
# TypeError handled: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## 3.10 IndexError
#
# IndexError occurs when we try to access an index that is outside
# the valid range of a sequence such as a list or tuple.

# %%
numbers = [10, 20, 30]

try:
    print(numbers[5])

except IndexError as error:
    print("IndexError handled:", error)
# Out:
# IndexError handled: list index out of range

# %% [markdown]
# ## 3.11 KeyError
#
# KeyError occurs when we try to access a dictionary using a key
# that is not present in the dictionary.

# %%
student = {
    "name": "Dileep",
    "course": "AI/ML",
    "year": 2026
}

try:
    print(student["age"])

except KeyError as error:
    print("KeyError handled:", error)
# Out:
# KeyError handled: 'age'

# %% [markdown]
# ## 3.12 AttributeError
#
# AttributeError occurs when we try to access an attribute or method
# that does not exist for an object.

# %%
class Student:
    def __init__(self, name):
        self.name = name


student = Student("Dileep")

try:
    print(student.age)

except AttributeError as error:
    print("AttributeError handled:", error)
# Out:
# AttributeError handled: 'Student' object has no attribute 'age'

# %% [markdown]
# ## 3.13 NameError
#
# NameError occurs when Python cannot find a variable, function,
# or other name because it has not been defined.

# %%
try:
    print(student_name)

except NameError as error:
    print("NameError handled:", error)
# Out:
# NameError handled: name 'student_name' is not defined

# %% [markdown]
# ## 3.14 FileNotFoundError
#
# FileNotFoundError occurs when a program tries to access a file
# that does not exist at the specified path.

# %%
try:
    with open("student_details.txt", "r") as file:
        data = file.read()
        print(data)

except FileNotFoundError as error:
    print("FileNotFoundError handled:", error)
# Out:
# FileNotFoundError handled: [Errno 2] No such file or directory: 'student_details.txt'

# %% [markdown]
# ## 3.15 ZeroDivisionError
#
# ZeroDivisionError occurs when a number is divided by zero.
# Python does not allow division by zero.

# %%
try:
    numerator = 100
    denominator = 0

    result = numerator / denominator
    print("Result:", result)

except ZeroDivisionError as error:
    print("ZeroDivisionError handled:", error)
# Out:
# ZeroDivisionError handled: division by zero

# %% [markdown]
# ## 3.16 ImportError
#
# ImportError occurs when Python finds the module but cannot
# import the requested name or component from that module.

# %%
try:
    from math import calculate_salary

except ImportError as error:
    print("ImportError handled:", error)
# Out:
# ImportError handled: cannot import name 'calculate_salary' from 'math' (unknown location)

# %% [markdown]
# ## 3.17 ModuleNotFoundError
#
# ModuleNotFoundError occurs when Python cannot find the module
# specified in an import statement.

# %%
try:
    import employee_management_system

except ModuleNotFoundError as error:
    print("ModuleNotFoundError handled:", error)
# Out:
# ModuleNotFoundError handled: No module named 'employee_management_system'

# %% [markdown]
# # Module 4 – Logging
#
# ## 4.1 What is Logging?
#
# Logging is the process of recording information about the execution
# of a program.
#
# Python provides the built-in logging module to record messages,
# warnings, errors, and other useful information.

# %%
import logging

logging.basicConfig(level=logging.INFO)

logging.info("Application started")
logging.warning("This is a warning message")
logging.error("An error occurred")
# Out:
# INFO:root:Application started
# WARNING:root:This is a warning message
# ERROR:root:An error occurred

# %% [markdown]
# ## 4.2 Why Use Logging?
#
# Logging is used to monitor application execution, track important events,
# identify errors, and troubleshoot problems.
#
# It is more flexible and manageable than using print() statements.

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(levelname)s: %(message)s"
)

user = "Dileep"

logging.info("User login started")
logging.info(f"User {user} logged in successfully")
logging.warning("Password will expire soon")
# Out:
# INFO:root:User login started
# INFO:root:User Dileep logged in successfully
# WARNING:root:Password will expire soon

# %% [markdown]
# ## 4.3 print() vs Logging
#
# print() is mainly used to display simple messages during development.
#
# Logging is more suitable for real applications because it supports
# different log levels, formatting, timestamps, and multiple destinations.

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

print("Application started")

logging.info("Application started")
logging.warning("Low memory detected")
logging.error("Unable to process the request")
# Out:
# INFO:root:Application started
# WARNING:root:Low memory detected
# ERROR:root:Unable to process the request
# Application started

# %% [markdown]
# ## 4.4 Log Levels
#
# Log levels indicate the severity or importance of a log message.
#
# The standard logging levels are:
#
# - DEBUG
# - INFO
# - WARNING
# - ERROR
# - CRITICAL

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format="%(levelname)s - %(message)s"
)

logging.debug("Debugging application flow")
logging.info("Application started successfully")
logging.warning("Memory usage is high")
logging.error("Failed to process the request")
logging.critical("System failure detected")
# Out:
# INFO:root:Application started successfully
# WARNING:root:Memory usage is high
# ERROR:root:Failed to process the request
# CRITICAL:root:System failure detected

# %% [markdown]
# ## 4.5 Log Formatters
#
# A log formatter defines the format and information included
# in a log message, such as timestamp, log level, and message.

# %%
import logging

logger = logging.getLogger("Application")
logger.setLevel(logging.INFO)

handler = logging.StreamHandler()

formatter = logging.Formatter(
    "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

handler.setFormatter(formatter)
logger.addHandler(handler)

logger.info("Application started")
logger.warning("Memory usage is high")
# Out:
# 2026-09-15 12:59:34,088 - Application - INFO - Application started
# INFO:Application:Application started
# 2026-09-15 12:59:34,090 - Application - WARNING - Memory usage is high
# WARNING:Application:Memory usage is high

# %% [markdown]
# ## 4.6 File Handlers
#
# A FileHandler is used to write logging messages to a file.
#
# It is useful for maintaining a persistent record of application
# events, warnings, and errors.

# %%
import logging

logger = logging.getLogger("FileLogger")
logger.setLevel(logging.INFO)

file_handler = logging.FileHandler("application.log")

formatter = logging.Formatter(
    "%(asctime)s - %(levelname)s - %(message)s"
)

file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

logger.info("Application started")
logger.warning("Low memory warning")
logger.error("An error occurred")

print("Logs written to application.log")
# Out:
# INFO:FileLogger:Application started
# WARNING:FileLogger:Low memory warning
# ERROR:FileLogger:An error occurred
# Logs written to application.log

# %% [markdown]
# ## 4.7 Console Handlers
#
# A ConsoleHandler is used to send logging messages to the console.
#
# It is useful for monitoring application activity while the program
# is running.

# %%
import logging

logger = logging.getLogger("ConsoleLogger")
logger.setLevel(logging.INFO)

console_handler = logging.StreamHandler()

formatter = logging.Formatter(
    "%(levelname)s - %(message)s"
)

console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

logger.info("Application started")
logger.warning("Memory usage is high")
logger.error("An error occurred")
# Out:
# INFO - Application started
# INFO:ConsoleLogger:Application started
# WARNING - Memory usage is high
# WARNING:ConsoleLogger:Memory usage is high
# ERROR - An error occurred
# ERROR:ConsoleLogger:An error occurred

# %% [markdown]
# ## 4.8 Rotating Logs
#
# Rotating logs prevent log files from growing indefinitely.
#
# RotatingFileHandler creates backup log files when the current
# log file reaches a specified size.

# %%
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("RotatingLogger")
logger.setLevel(logging.INFO)

# Remove existing handlers to avoid file-locking and duplicate logs
for handler in logger.handlers[:]:
    handler.close()
    logger.removeHandler(handler)

handler = RotatingFileHandler(
    "rotating_application.log",
    maxBytes=200,
    backupCount=3
)

formatter = logging.Formatter(
    "%(asctime)s - %(levelname)s - %(message)s"
)

handler.setFormatter(formatter)
logger.addHandler(handler)

for i in range(20):
    logger.info(f"Application event number {i}")

handler.close()

print("Rotating logs created successfully.")
# Out:
# INFO:RotatingLogger:Application event number 0
# INFO:RotatingLogger:Application event number 1
# INFO:RotatingLogger:Application event number 2
# INFO:RotatingLogger:Application event number 3
# INFO:RotatingLogger:Application event number 4
# INFO:RotatingLogger:Application event number 5
# INFO:RotatingLogger:Application event number 6
# INFO:RotatingLogger:Application event number 7
# INFO:RotatingLogger:Application event number 8
# INFO:RotatingLogger:Application event number 9
# INFO:RotatingLogger:Application event number 10
# INFO:RotatingLogger:Application event number 11
# INFO:RotatingLogger:Application event number 12
# INFO:RotatingLogger:Application event number 13
# INFO:RotatingLogger:Application event number 14
# INFO:RotatingLogger:Application event number 15
# INFO:RotatingLogger:Application event number 16
# INFO:RotatingLogger:Application event number 17
# INFO:RotatingLogger:Application event number 18
# INFO:RotatingLogger:Application event number 19
# ...

# %% [markdown]
# ## 4.9 Logging Best Practices
#
# Good logging practices make applications easier to monitor,
# debug, and maintain.
#
# Important practices include:
#
# - Use appropriate log levels.
# - Write meaningful log messages.
# - Include useful contextual information.
# - Never log passwords, API keys, or sensitive information.
# - Use logging instead of excessive print() statements.
# - Use file or console handlers as required.
# - Use log rotation to control log file size.

# %%
import logging

logger = logging.getLogger("Application")
logger.setLevel(logging.INFO)

handler = logging.StreamHandler()

formatter = logging.Formatter(
    "%(asctime)s - %(levelname)s - %(message)s"
)

handler.setFormatter(formatter)
logger.addHandler(handler)

user = "Dileep"

logger.info(f"User {user} logged in successfully")
logger.warning("Password will expire soon")
logger.error("Unable to process the request")
# Out:
# 2026-09-16 12:21:50,775 - INFO - User Dileep logged in successfully
# 2026-09-16 12:21:50,777 - WARNING - Password will expire soon
# 2026-09-16 12:21:50,779 - ERROR - Unable to process the request

# %% [markdown]
# # Module 5 – File Handling
#
# File handling allows Python programs to create, read, write,
# modify, and manage files and directories.
#
# ### Topics Covered
#
# - 5.1 Reading Text Files
# - 5.2 Writing Text Files
# - 5.3 CSV Files
# - 5.4 JSON Files
# - 5.5 Pickle Files
# - 5.6 Context Manager (with)
# - 5.7 pathlib
# - 5.8 os
# - 5.9 shutil
# - 5.10 File Validation
# - 5.11 Directory Operations

# %% [markdown]
# ## 5.1 Reading Text Files
#
# The open() function can be used to access a text file.
# The "r" mode is used to read the contents of an existing file.

# %%
# Create a sample text file
file = open("student.txt", "w")
file.write("Name: Dileep\n")
file.write("Course: AI/ML\n")
file.write("Year: 2026\n")
file.close()

# Read the text file
file = open("student.txt", "r")
content = file.read()
file.close()

print("File Content:")
print(content)
# Out:
# File Content:
# Name: Dileep
# Course: AI/ML
# Year: 2026

# %% [markdown]
# ## 5.2 Writing Text Files
#
# The "w" mode is used to write data into a text file.
#
# If the file does not exist, Python creates it.
# If the file already exists, its previous content is overwritten.

# %%
file = open("employee.txt", "w")

file.write("Employee Name: Dileep\n")
file.write("Role: AI/ML Engineer\n")
file.write("Experience: Fresher\n")

file.close()

print("Data written successfully.")

# Verify the written data
file = open("employee.txt", "r")
print("\nFile Content:")
print(file.read())
file.close()
# Out:
# Data written successfully.
#
# File Content:
# Employee Name: Dileep
# Role: AI/ML Engineer
# Experience: Fresher

# %% [markdown]
# ## 5.3 CSV Files
#
# CSV files store tabular data in rows and columns.
# Python provides the built-in csv module to read and write CSV files.

# %%
import csv

# Write data to a CSV file
students = [
    ["Name", "Course", "Marks"],
    ["Dileep", "AI/ML", 85],
    ["Rahul", "Data Science", 90],
    ["Anil", "Python", 88]
]

with open("students.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(students)

# Read data from the CSV file
with open("students.csv", "r") as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['Name', 'Course', 'Marks']
# ['Dileep', 'AI/ML', '85']
# ['Rahul', 'Data Science', '90']
# ['Anil', 'Python', '88']

# %% [markdown]
# ## 5.4 JSON Files
#
# JSON is a lightweight format used to store and exchange structured data.
#
# Python provides the built-in json module to read and write JSON files.

# %%
import json

student = {
    "name": "Dileep",
    "course": "AI/ML",
    "year": 2026,
    "skills": ["Python", "Machine Learning", "SQL"]
}

# Write data to a JSON file
with open("student.json", "w") as file:
    json.dump(student, file, indent=4)

# Read data from the JSON file
with open("student.json", "r") as file:
    data = json.load(file)

print("Student Name:", data["name"])
print("Course:", data["course"])
print("Skills:", data["skills"])
# Out:
# Student Name: Dileep
# Course: AI/ML
# Skills: ['Python', 'Machine Learning', 'SQL']

# %% [markdown]
# ## 5.5 Pickle Files
#
# The pickle module is used to serialize Python objects and save them
# to a file.
#
# It can also deserialize the stored data and recreate the original object.

# %%
import pickle

student = {
    "name": "Dileep",
    "course": "AI/ML",
    "marks": [85, 90, 88]
}

# Save the Python object
with open("student.pkl", "wb") as file:
    pickle.dump(student, file)

# Load the Python object
with open("student.pkl", "rb") as file:
    loaded_student = pickle.load(file)

print("Student Name:", loaded_student["name"])
print("Course:", loaded_student["course"])
print("Marks:", loaded_student["marks"])
# Out:
# Student Name: Dileep
# Course: AI/ML
# Marks: [85, 90, 88]

# %% [markdown]
# ## 5.6 Context Manager (with)
#
# The with statement is used as a context manager for handling resources.
#
# When working with files, it automatically closes the file after
# the operation is completed.

# %%
with open("context_example.txt", "w") as file:
    file.write("Learning Python File Handling")

print("Data written successfully.")

with open("context_example.txt", "r") as file:
    content = file.read()

print("File Content:", content)
print("File automatically closed:", file.closed)
# Out:
# Data written successfully.
# File Content: Learning Python File Handling
# File automatically closed: True

# %% [markdown]
# ## 5.7 pathlib
#
# The pathlib module provides an object-oriented way to work with
# file and directory paths.
#
# It can be used to create paths, check whether files exist,
# and access file information.

# %%
from pathlib import Path

file_path = Path("student.txt")

print("File Name:", file_path.name)
print("File Exists:", file_path.exists())
print("File Extension:", file_path.suffix)

if file_path.exists():
    print("File Content:")
    print(file_path.read_text())
# Out:
# File Name: student.txt
# File Exists: True
# File Extension: .txt
# File Content:
# Name: Dileep
# Course: AI/ML
# Year: 2026

# %% [markdown]
# ## 5.8 os
#
# The os module provides functions for interacting with the operating system.
#
# It can be used to work with files, directories, paths, and environment information.

# %%
import os

current_directory = os.getcwd()

print("Current Directory:")
print(current_directory)

print("\nFiles and Directories:")
for item in os.listdir(current_directory):
    print(item)
# Out:
# Current Directory:
# C:\Users\dilee
#
# Files and Directories:
# .anaconda
# .aws
# .azure
# .cagent
# .conda
# .config
# .continuum
# .copilot
# .cursor
# .docker
# .gemini
# .git
# .gitconfig
# .idlerc
# .ipynb_checkpoints
# .ipython
# .jupyter
# .kube
# .lesshst
# .matplotlib
# .minikube
# .ollama
# .Python_Data_Processing_Assessment.ipynb.layout
# .streamlit
# AppData
# Application Data
# application.log
# banking.db
# config.json
# Contacts
# context_example.txt
# Cookies
# Documents
# Downloads
# employee.txt
# employees.db
# employees_output.csv
# employees_task2.csv
# Favorites
# hospital_project
# inputs
# Links
# Local Settings
# logs
# Module_1_Python_Fundamentals.ipynb
# Music
# My Documents
# NetHood
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{8cc2add6-0878-11f1-ba44-a083c5b06cd3}.TM.blf
# NTUSER.DAT{8cc2add6-0878-11f1-ba44-a083c5b06cd3}.TMContainer00000000000000000001.regtrans-ms
# ...

# %% [markdown]
# ## 5.9 shutil
#
# The `shutil` module is used for high-level file and directory operations.
#
# It can be used to:
# - Copy files
# - Copy directories
# - Move files
# - Delete directories

# %%
import shutil
import os

# Create a source file
with open("source.txt", "w") as file:
    file.write("This is the source file.")

# Copy the file
shutil.copy("source.txt", "copy_source.txt")

print("File copied successfully.")

# Move the copied file
shutil.move("copy_source.txt", "moved_source.txt")

print("File moved successfully.")

# Check whether the moved file exists
print("Moved file exists:", os.path.exists("moved_source.txt"))
# Out:
# File copied successfully.
# File moved successfully.
# Moved file exists: True

# %% [markdown]
# ## 5.10 File Validation
#
# File validation is used to check whether a file exists and whether it has
# the expected file type or extension before processing it.

# %%
from pathlib import Path

file_path = Path("student.txt")

# Check whether file exists
if file_path.exists():
    print("File exists.")

    # Validate file extension
    if file_path.suffix == ".txt":
        print("Valid text file.")
    else:
        print("Invalid file type.")
else:
    print("File does not exist.")
# Out:
# File exists.
# Valid text file.

# %% [markdown]
# ## 5.11 Directory Operations
#
# Directory operations are used to create, list, rename, and remove
# directories using Python.
#
# Python provides modules such as `os` and `pathlib` for directory management.

# %%
import os
from pathlib import Path

# Create a directory
folder = Path("project_folder")

if not folder.exists():
    folder.mkdir()
    print("Directory created.")
else:
    print("Directory already exists.")

# Create a file inside the directory
file_path = folder / "example.txt"

with open(file_path, "w") as file:
    file.write("Directory operations in Python.")

print("File created inside the directory.")

# List files and folders
print("\nDirectory Contents:")
for item in folder.iterdir():
    print(item.name)

# Check directory
print("\nIs directory:", folder.is_dir())
# Out:
# Directory created.
# File created inside the directory.
#
# Directory Contents:
# example.txt
#
# Is directory: True

# %% [markdown]
# # Module 6 – SQL
#
# SQL (Structured Query Language) is used to store, retrieve,
# and manage data in relational databases.
#
# This module covers database design, SQL queries, joins,
# and advanced SQL concepts.
#
# We will use SQLite for the examples.

# %% [markdown]
# ## 6.1 Database
#
# A database is an organized collection of data that allows
# information to be stored, managed, and retrieved efficiently.
#
# SQLite creates a database as a file, while other databases
# such as MySQL and PostgreSQL can use database servers.

# %%
import sqlite3

# Create/connect to the database
connection = sqlite3.connect("company.db")

# Create cursor
cursor = connection.cursor()

print("Database connected successfully.")
# Out:
# Database connected successfully.

# %%
# Create a database table
cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    employee_id INTEGER,
    name TEXT,
    department TEXT,
    salary REAL
)
""")

connection.commit()

print("Database and employees table created successfully.")
# Out:
# Database and employees table created successfully.

# %% [markdown]
# ## 6.2 Tables
#
# A table stores data in rows and columns.
#
# - Columns represent attributes or fields.
# - Rows represent individual records.
# - A table is created using the CREATE TABLE statement.

# %%
# Insert employee records into the table
employees = [
    (1, "Dileep", "AI/ML", 900000),
    (2, "Rahul", "Data Science", 800000),
    (3, "Anil", "Cloud", 750000),
    (4, "Kiran", "AI/ML", 850000)
]

cursor.executemany("""
INSERT INTO employees (employee_id, name, department, salary)
VALUES (?, ?, ?, ?)
""", employees)

connection.commit()

# Display table data
cursor.execute("SELECT * FROM employees")

for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Dileep', 'AI/ML', 900000.0)
# (2, 'Rahul', 'Data Science', 800000.0)
# (3, 'Anil', 'Cloud', 750000.0)
# (4, 'Kiran', 'AI/ML', 850000.0)

# %% [markdown]
# ## 6.3 Primary Key
#
# A primary key is a column or combination of columns that uniquely
# identifies each record in a table.
#
# A primary key:
# - Must contain unique values.
# - Cannot contain NULL values.
# - Identifies each row uniquely.

# %%
import sqlite3

connection = sqlite3.connect("primary_key_demo.db")
cursor = connection.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    employee_id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary REAL
)
""")

employees = [
    (1, "Dileep", "AI/ML", 900000),
    (2, "Rahul", "Data Science", 800000),
    (3, "Anil", "Cloud", 750000)
]

cursor.executemany("""
INSERT OR IGNORE INTO employees
(employee_id, name, department, salary)
VALUES (?, ?, ?, ?)
""", employees)

connection.commit()

cursor.execute("SELECT * FROM employees")

for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Dileep', 'AI/ML', 900000.0)
# (2, 'Rahul', 'Data Science', 800000.0)
# (3, 'Anil', 'Cloud', 750000.0)

# %% [markdown]
# ## 6.4 Foreign Key
#
# A foreign key is a column that creates a relationship between
# two tables.
#
# It references the primary key of another table and helps maintain
# referential integrity between related tables.

# %%
import sqlite3

connection = sqlite3.connect("foreign_key_demo.db")
cursor = connection.cursor()

# Enable foreign key support in SQLite
cursor.execute("PRAGMA foreign_keys = ON")

# Parent table
cursor.execute("""
CREATE TABLE IF NOT EXISTS departments (
    department_id INTEGER PRIMARY KEY,
    department_name TEXT
)
""")

# Child table
cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    employee_id INTEGER PRIMARY KEY,
    name TEXT,
    department_id INTEGER,
    FOREIGN KEY (department_id)
        REFERENCES departments(department_id)
)
""")

# Insert department data
cursor.execute("""
INSERT OR IGNORE INTO departments
VALUES (1, 'AI/ML')
""")

# Insert employee linked to department
cursor.execute("""
INSERT OR IGNORE INTO employees
VALUES (101, 'Dileep', 1)
""")

connection.commit()

cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
JOIN departments
ON employees.department_id = departments.department_id
""")

for row in cursor.fetchall():
    print(row)
# Out:
# ('Dileep', 'AI/ML')

# %% [markdown]
# ## 6.5 Relationships
#
# Relationships define how tables are connected to each other.
#
# Common types of relationships are:
#
# - One-to-One (1:1)
# - One-to-Many (1:M)
# - Many-to-Many (M:M)
#
# Foreign keys are commonly used to establish relationships between tables.

# %%
import sqlite3

connection = sqlite3.connect("relationships_demo.db")
cursor = connection.cursor()

# Department table
cursor.execute("""
CREATE TABLE IF NOT EXISTS departments (
    department_id INTEGER PRIMARY KEY,
    department_name TEXT
)
""")

# Employee table
cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    employee_id INTEGER PRIMARY KEY,
    name TEXT,
    department_id INTEGER,
    FOREIGN KEY (department_id)
        REFERENCES departments(department_id)
)
""")

# Insert departments
cursor.executemany("""
INSERT OR IGNORE INTO departments
VALUES (?, ?)
""", [
    (1, "AI/ML"),
    (2, "Cloud")
])

# Insert employees
cursor.executemany("""
INSERT OR IGNORE INTO employees
VALUES (?, ?, ?)
""", [
    (101, "Dileep", 1),
    (102, "Rahul", 1),
    (103, "Anil", 2)
])

connection.commit()

# Display relationship
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
JOIN departments
ON employees.department_id = departments.department_id
""")

for row in cursor.fetchall():
    print(row)
# Out:
# ('Dileep', 'AI/ML')
# ('Rahul', 'AI/ML')
# ('Anil', 'Cloud')

# %% [markdown]
# ## 6.6 Constraints
#
# Constraints are rules applied to table columns to maintain
# data accuracy and integrity.
#
# Common SQL constraints include:
#
# - PRIMARY KEY
# - FOREIGN KEY
# - NOT NULL
# - UNIQUE
# - CHECK
# - DEFAULT

# %%
import sqlite3

connection = sqlite3.connect("constraints_demo.db")
cursor = connection.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    employee_id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    email TEXT UNIQUE,
    salary REAL CHECK(salary > 0),
    department TEXT DEFAULT 'AI/ML'
)
""")

cursor.execute("""
INSERT OR IGNORE INTO employees
(employee_id, name, email, salary)
VALUES (?, ?, ?, ?)
""", (1, "Dileep", "dileep@example.com", 900000))

connection.commit()

cursor.execute("SELECT * FROM employees")

for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Dileep', 'dileep@example.com', 900000.0, 'AI/ML')

# %% [markdown]
# ## 6.7 SELECT
#
# The SELECT statement is used to retrieve data from a database table.
#
# It can be used to retrieve:
# - All columns
# - Specific columns
# - Selected records

# %%
# Select all columns
cursor.execute("""
SELECT * FROM employees
""")

print("All Employee Records:")

for row in cursor.fetchall():
    print(row)
# Out:
# All Employee Records:
# (1, 'Dileep', 'dileep@example.com', 900000.0, 'AI/ML')

# %% [markdown]
# ## 6.8 WHERE
#
# The WHERE clause is used to filter records based on a condition.
#
# It returns only the rows that satisfy the specified condition.

# %%
# Find employees from the AI/ML department
cursor.execute("""
SELECT name, department, salary
FROM employees
WHERE department = 'AI/ML'
""")

print("AI/ML Employees:")

for row in cursor.fetchall():
    print(row)
# Out:
# AI/ML Employees:
# ('Dileep', 'AI/ML', 900000.0)

# %% [markdown]
# ## 6.9 ORDER BY
#
# The ORDER BY clause is used to sort query results.
#
# - ASC → ascending order (default)
# - DESC → descending order

# %%
# Sort employees by salary from highest to lowest
cursor.execute("""
SELECT name, department, salary
FROM employees
ORDER BY salary DESC
""")

print("Employees sorted by salary:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees sorted by salary:
# ('Dileep', 'AI/ML', 900000.0)

# %% [markdown]
# ## 6.10 GROUP BY
#
# The GROUP BY clause groups rows that have the same values.
#
# It is commonly used with aggregate functions such as:
# - COUNT()
# - SUM()
# - AVG()
# - MAX()
# - MIN()

# %%
# Count employees in each department
cursor.execute("""
SELECT department, COUNT(*) AS employee_count
FROM employees
GROUP BY department
""")

print("Employees by department:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees by department:
# ('AI/ML', 1)

# %% [markdown]
# ## 6.11 HAVING
#
# The HAVING clause is used to filter grouped results.
#
# It is commonly used with GROUP BY and aggregate functions
# such as COUNT(), SUM(), and AVG().

# %%
# Find departments having more than 1 employee
cursor.execute("""
SELECT department, COUNT(*) AS employee_count
FROM employees
GROUP BY department
HAVING COUNT(*) > 1
""")

print("Departments with more than 1 employee:")

for row in cursor.fetchall():
    print(row)
# Out:
# Departments with more than 1 employee:

# %% [markdown]
# ## 6.12 DISTINCT
#
# The DISTINCT keyword is used to remove duplicate values
# from the query result.

# %%
# Get unique departments
cursor.execute("""
SELECT DISTINCT department
FROM employees
""")

print("Unique Departments:")

for row in cursor.fetchall():
    print(row[0])
# Out:
# Unique Departments:
# AI/ML

# %% [markdown]
# ## 6.13 LIMIT
#
# The LIMIT clause is used to restrict the number of rows
# returned by a SQL query.

# %%
# Display only the first 2 employees
cursor.execute("""
SELECT name, department, salary
FROM employees
LIMIT 2
""")

print("First 2 Employees:")

for row in cursor.fetchall():
    print(row)
# Out:
# First 2 Employees:
# ('Dileep', 'AI/ML', 900000.0)

# %% [markdown]
# ## 6.14 INNER JOIN
#
# INNER JOIN combines rows from two tables when there is
# a matching value between them.
#
# Only matching records from both tables are returned.

# %%
# Create department table
cursor.execute("""
CREATE TABLE IF NOT EXISTS departments (
    department_id INTEGER PRIMARY KEY,
    department_name TEXT
)
""")

# Insert department data
cursor.executemany("""
INSERT OR IGNORE INTO departments
VALUES (?, ?)
""", [
    (1, "AI/ML"),
    (2, "Data Science"),
    (3, "Cloud")
])

# Add department IDs to employees
cursor.execute("ALTER TABLE employees ADD COLUMN department_id INTEGER")

# Update employee department IDs
cursor.execute("""
UPDATE employees
SET department_id =
    CASE department
        WHEN 'AI/ML' THEN 1
        WHEN 'Data Science' THEN 2
        WHEN 'Cloud' THEN 3
    END
""")

connection.commit()

# INNER JOIN
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
INNER JOIN departments
ON employees.department_id = departments.department_id
""")

print("Employee and Department:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employee and Department:
# ('Dileep', 'AI/ML')

# %% [markdown]
# ## 6.15 LEFT JOIN
#
# LEFT JOIN returns all records from the left table and
# the matching records from the right table.
#
# If there is no match, the right-side columns contain NULL.

# %%
# LEFT JOIN employees with departments
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
LEFT JOIN departments
ON employees.department_id = departments.department_id
""")

print("LEFT JOIN Result:")

for row in cursor.fetchall():
    print(row)
# Out:
# LEFT JOIN Result:
# ('Dileep', 'AI/ML')

# %% [markdown]
# ## 6.16 RIGHT JOIN
#
# RIGHT JOIN returns all records from the right table and
# the matching records from the left table.
#
# If there is no match, the left-side columns contain NULL.

# %%
# RIGHT JOIN departments with employees
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
RIGHT JOIN departments
ON employees.department_id = departments.department_id
""")

print("RIGHT JOIN Result:")

for row in cursor.fetchall():
    print(row)
# Out:
# RIGHT JOIN Result:
# ('Dileep', 'AI/ML')
# (None, 'Data Science')
# (None, 'Cloud')

# %% [markdown]
# ## 6.17 FULL JOIN
#
# FULL JOIN returns all records from both tables.
#
# If a record has no matching value in the other table,
# NULL is returned for the missing columns.

# %%
# FULL JOIN employees and departments
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
FULL OUTER JOIN departments
ON employees.department_id = departments.department_id
""")

print("FULL JOIN Result:")

for row in cursor.fetchall():
    print(row)
# Out:
# FULL JOIN Result:
# ('Dileep', 'AI/ML')
# (None, 'Data Science')
# (None, 'Cloud')

# %%
# FULL JOIN employees and departments
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
FULL OUTER JOIN departments
ON employees.department_id = departments.department_id
""")

print("FULL JOIN Result:")

for row in cursor.fetchall():
    print(row)
# Out:
# FULL JOIN Result:
# ('Dileep', 'AI/ML')
# (None, 'Data Science')
# (None, 'Cloud')

# %% [markdown]
# ## 6.18 CROSS JOIN
#
# CROSS JOIN returns the Cartesian product of two tables.
#
# Each row from the first table is combined with every row
# from the second table.

# %%
# CROSS JOIN departments with employees
cursor.execute("""
SELECT employees.name, departments.department_name
FROM employees
CROSS JOIN departments
""")

print("CROSS JOIN Result:")

for row in cursor.fetchall():
    print(row)
# Out:
# CROSS JOIN Result:
# ('Dileep', 'AI/ML')
# ('Dileep', 'Data Science')
# ('Dileep', 'Cloud')

# %% [markdown]
# ## 6.19 UNION
#
# The UNION operator combines the results of two or more SELECT queries.
#
# UNION removes duplicate records from the combined result.

# %%
# Create two simple result sets and combine them
cursor.execute("""
SELECT name FROM employees
WHERE department = 'AI/ML'

UNION

SELECT name FROM employees
WHERE salary > 800000
""")

print("Combined Employee Names:")

for row in cursor.fetchall():
    print(row[0])
# Out:
# Combined Employee Names:
# Dileep

# %% [markdown]
# ## 6.20 CASE
#
# The CASE expression is used to perform conditional logic in SQL.
#
# It works similar to if-elif-else statements in Python.

# %%
cursor.execute("""
SELECT name, salary,
CASE
    WHEN salary >= 850000 THEN 'High Salary'
    WHEN salary >= 750000 THEN 'Medium Salary'
    ELSE 'Low Salary'
END AS salary_category
FROM employees
""")

print("Employee Salary Categories:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employee Salary Categories:
# ('Dileep', 900000.0, 'High Salary')

# %% [markdown]
# ## 6.21 Subqueries
#
# A subquery is a SQL query written inside another SQL query.
#
# The inner query is executed first, and its result is used
# by the outer query.

# %%
# Find employees earning more than the average salary
cursor.execute("""
SELECT name, salary
FROM employees
WHERE salary > (
    SELECT AVG(salary)
    FROM employees
)
""")

print("Employees earning above average salary:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees earning above average salary:

# %% [markdown]
# ## 6.22 Common Table Expressions (CTEs)
#
# A Common Table Expression (CTE) is a temporary named result set
# that can be used within a SQL query.
#
# CTEs are created using the WITH keyword and make complex queries
# easier to read and maintain.

# %%
# Use a CTE to calculate average salary
cursor.execute("""
WITH average_salary AS (
    SELECT AVG(salary) AS avg_salary
    FROM employees
)
SELECT name, salary
FROM employees, average_salary
WHERE salary > average_salary.avg_salary
""")

print("Employees above average salary:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees above average salary:

# %% [markdown]
# ## 6.23 Views
#
# A view is a virtual table created from the result of a SQL query.
#
# Views are useful for:
# - Simplifying complex queries
# - Reusing frequently used queries
# - Controlling which data users can access

# %%
# Create a view for AI/ML employees
cursor.execute("""
CREATE VIEW IF NOT EXISTS ai_ml_employees AS
SELECT name, salary
FROM employees
WHERE department = 'AI/ML'
""")

# Read data from the view
cursor.execute("""
SELECT * FROM ai_ml_employees
""")

print("AI/ML Employees:")

for row in cursor.fetchall():
    print(row)
# Out:
# AI/ML Employees:
# ('Dileep', 900000.0)

# %% [markdown]
# ## 6.24 Indexes
#
# An index is a database structure used to improve the speed
# of data retrieval.
#
# Indexes are especially useful when frequently searching,
# filtering, or sorting data using a particular column.

# %%
# Create an index on the department column
cursor.execute("""
CREATE INDEX IF NOT EXISTS idx_employee_department
ON employees(department)
""")

connection.commit()

print("Index created successfully.")

# Use the indexed column in a query
cursor.execute("""
SELECT name, department
FROM employees
WHERE department = 'AI/ML'
""")

for row in cursor.fetchall():
    print(row)
# Out:
# Index created successfully.
# ('Dileep', 'AI/ML')

# %% [markdown]
# ## 6.25.1 ROW_NUMBER()
#
# ROW_NUMBER() assigns a unique sequential number to each row
# within a result set.
#
# It is commonly used with ORDER BY inside the OVER() clause.

# %%
cursor.execute("""
SELECT
    name,
    department,
    salary,
    ROW_NUMBER() OVER (ORDER BY salary DESC) AS row_number
FROM employees
""")

print("Employees with Row Numbers:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees with Row Numbers:
# ('Dileep', 'AI/ML', 900000.0, 1)

# %% [markdown]
# ## 6.25.2 RANK()
#
# RANK() assigns a ranking to rows based on a specified order.
#
# If two rows have the same value, they receive the same rank,
# and the next rank is skipped.

# %%
cursor.execute("""
SELECT
    name,
    department,
    salary,
    RANK() OVER (ORDER BY salary DESC) AS salary_rank
FROM employees
""")

print("Employees Ranked by Salary:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees Ranked by Salary:
# ('Dileep', 'AI/ML', 900000.0, 1)

# %% [markdown]
# ## 6.25.3 DENSE_RANK()
#
# DENSE_RANK() assigns a rank to each row based on a specified order.
#
# If two rows have the same value, they receive the same rank,
# but unlike RANK(), the next rank is not skipped.

# %%
cursor.execute("""
SELECT
    name,
    department,
    salary,
    DENSE_RANK() OVER (ORDER BY salary DESC) AS salary_rank
FROM employees
""")

print("Employees with Dense Rank:")

for row in cursor.fetchall():
    print(row)
# Out:
# Employees with Dense Rank:
# ('Dileep', 'AI/ML', 900000.0, 1)

# %% [markdown]
# ## 6.25.4 LAG()
#
# LAG() is a window function used to access a value from
# a previous row without using a self-join.
#
# It is useful for comparing the current row with a previous row.

# %%
cursor.execute("""
SELECT
    name,
    salary,
    LAG(salary) OVER (ORDER BY salary DESC) AS previous_salary
FROM employees
""")

print("Salary Comparison:")

for row in cursor.fetchall():
    print(row)
# Out:
# Salary Comparison:
# ('Dileep', 900000.0, None)

# %% [markdown]
# ## 6.25.5 LEAD()
#
# LEAD() is a window function used to access a value from
# the next row without using a self-join.
#
# It is useful for comparing the current row with a following row.

# %%
cursor.execute("""
SELECT
    name,
    salary,
    LEAD(salary) OVER (ORDER BY salary DESC) AS next_salary
FROM employees
""")

print("Salary Comparison:")

for row in cursor.fetchall():
    print(row)
# Out:
# Salary Comparison:
# ('Dileep', 900000.0, None)
